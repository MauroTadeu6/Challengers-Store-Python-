# %% [markdown]
# <a href="https://colab.research.google.com/github/MauroTadeu6/Challengers-Store-Python-/blob/main/AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja_1 = pd.read_csv(url)
loja_2 = pd.read_csv(url2)
loja_3 = pd.read_csv(url3)
loja_4 = pd.read_csv(url4)

loja_1.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
import matplotlib.pyplot as plt

# %%
# Faturamento por Loja

# %%
faturam_Tot_Loja1 = loja_1['Preço'].sum()

# %%
faturam_Tot_Loja2 = loja_2['Preço'].sum()

# %%
faturam_Tot_Loja3 = loja_3['Preço'].sum()

# %%
faturam_Tot_Loja4 = loja_4['Preço'].sum()

# %%
# Formatando valores para R$

# %%
def formatar(valor):
  return 'R${:,.2f}'.format(valor).replace(',', 'x').replace('.',',').replace('x','.')

# %%
valor_formatado_1 = formatar(faturam_Tot_Loja1)
print(f"\033[32mLoja 1\033[0m - O faturamento foi de: \033[32m{valor_formatado_1}\033[0m")
valor_formatado_2 = formatar(faturam_Tot_Loja2)
print(f"\033[33mLoja 2\033[0m - O faturamento foi de: \033[33m{valor_formatado_2}\033[0m")
valor_formatado_3 = formatar(faturam_Tot_Loja3)
print(f"\033[34mLoja 3\033[0m - O faturamento foi de: \033[34m{valor_formatado_3}\033[0m")
valor_formatado_4 = formatar(faturam_Tot_Loja4)
print(f"\033[35mLoja 4\033[0m- O faturamento foi de: \033[35m{valor_formatado_4}\033[0m")
# Out:
# Loja 1 - O faturamento foi de: R$1.534.509,12
# Loja 2 - O faturamento foi de: R$1.488.459,06
# Loja 3 - O faturamento foi de: R$1.464.025,03
# Loja 4- O faturamento foi de: R$1.384.497,58

# %%
stores=['loja_1','loja_2','loja_3','loja_4']
faturam_total=[faturam_Tot_Loja1,faturam_Tot_Loja2,faturam_Tot_Loja3,faturam_Tot_Loja4]

# %%
#Gráfico de Barras - Faturamento por Loja

# %%
plt.figure(figsize=(15,6))
cores=plt.cm.tab20(range(len(stores)))
plt.bar(stores,faturam_total,color=cores)
for i, valor in enumerate(faturam_total):
  plt.text(i,valor+0.025,f'R${valor:,.2f}',ha='center',va='bottom',color='green')
plt.xlabel('Stores', color='y')
plt.ylabel('Faturamento (MR$)', color='green')
plt.title('Faturamento por Loja',color='red')
# Out:
# Text(0.5, 1.0, 'Faturamento por Loja')

# %%
# Gráfico de Pizza - Distribuição do Faturamento por loja

# %%
plt.pie(faturam_total,labels=stores,autopct='%2.0f%%')
plt.title('Divisão por Loja', color='red')
# Out:
# Text(0.5, 1.0, 'Divisão por Loja')

# %% [markdown]
# # 2. Vendas por Categoria

# %%
# Sales by Categroy

# %%
category_products_1=loja_1['Categoria do Produto'].value_counts()
print(f'\033[31mLoja 1\033[0m- Sales by Category:\n{category_products_1}')
print()
category_products_2=loja_2['Categoria do Produto'].value_counts()
print(f'\033[31mLoja 2\033[0m- Sales by Category:\n{category_products_2}')
print()
category_products_3=loja_3['Categoria do Produto'].value_counts()
print(f'\033[31mLoja 3\033[0m- Sales by Category:\n{category_products_3}')
print()
category_products_4=loja_4['Categoria do Produto'].value_counts()
print(f'\033[31mLoja 4\033[0m- Sales by Category:\n{category_products_4}')
# Out:
# Loja 1- Sales by Category:
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: count, dtype: int64
#
# Loja 2- Sales by Category:
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: count, dtype: int64
#
# Loja 3- Sales by Category:
# Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# Name: count, dtype: int64
#
# ...

# %%
# Grafico de Categoria de Produtos por loja

# %%
df_categories = pd.DataFrame({'Loja 1':category_products_1,
                              'Loja 2':category_products_2,
                              'Loja 3':category_products_3,
                              'Loja 4':category_products_4
                              })
ax=df_categories.plot(kind='bar',figsize=(15,7))
ax.set_title('Category Product Sales by Store',color='red')
ax.set_xlabel('Category of Products', color='y')
ax.set_ylabel('Numbers of Sales',color='green')
plt.xticks(rotation=20)
plt.legend(title= 'Stores')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
avaliação_media_1=loja_1['Avaliação da compra'].mean().round(2)
print(f'\033[31mLOJA 1\033[0m - Avaliação média = \033[32m{avaliação_media_1}\033[0m')
avaliação_media_2=loja_2['Avaliação da compra'].mean().round(2)
print(f'\033[31mLOJA 2\033[0m - Avaliação média = \033[32m{avaliação_media_2}\033[0m')
avaliação_media_3=loja_3['Avaliação da compra'].mean().round(2)
print(f'\033[31mLOJA 3\033[0m - Avaliação média = \033[32m{avaliação_media_3}\033[0m')
avaliação_media_4=loja_4['Avaliação da compra'].mean().round(2)
print(f'\033[31mLOJA 4\033[0m - Avaliação média = \033[32m{avaliação_media_4}\033[0m')
# Out:
# LOJA 1 - Avaliação média = 3.98
# LOJA 2 - Avaliação média = 4.04
# LOJA 3 - Avaliação média = 4.05
# LOJA 4 - Avaliação média = 4.0

# %%
# Grafico de Linhas - Avaliação dos Clientes por Loja

# %%
media_avaliação=[loja_1['Avaliação da compra'].mean(),
                   loja_2['Avaliação da compra'].mean(),
                   loja_3['Avaliação da compra'].mean(),
                   loja_4['Avaliação da compra'].mean()] #.mean()calcula a média das reclamações por loja
plt.figure(figsize=(8,6))
plt.plot(stores, media_avaliação, marker='o', linestyle='-', color='purple')
for i, valor in enumerate(media_avaliação):
  plt.text( i, valor + 0.01,f'{valor:.2f}', ha= 'center',va='center',color='blue')
plt.ylim(3.9,max(media_avaliação)+0.1)
plt.title('Avaliação méda dos clientes por loja', color='red')
plt.xlabel('Lojas', color='green')
plt.ylabel('Média de Reclamações', color='y')
plt.grid(True)
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
lista_produt_Lj1 = loja_1['Produto'].value_counts()
mais_vendido_1 = lista_produt_Lj1.nlargest(6)
print("\033[31mLOJA 1\033[0m- Produtos \033[31mMAIS\033[0m vendidos:")
for produto, quantidade in mais_vendido_1.items():
    print(f"{produto} com: {quantidade} unid")
menos_vendido_1 = lista_produt_Lj1.nsmallest(6)
print("\n\033[31mLOJA 1\033[0m -Produtos \033[31mMENOS\033[0m vendidos =")
for produto, quantidade in menos_vendido_1.items():
    print(f"{produto} com: {quantidade} unid")

lista_produt_Lj2 = loja_2['Produto'].value_counts()
mais_vendido_2 = lista_produt_Lj2.nlargest(6)
print("\n\033[31mLOJA 2\033[0m- Produtos \033[31mMAIS\033[0m vendidos:")
for produto, quantidade in mais_vendido_2.items():
    print(f"{produto} com: {quantidade} unid")
menos_vendido_2 = lista_produt_Lj2.nsmallest(6)
print("\n\033[31mLOJA 2\033[0m -Produtos \033[31mMENOS\033[0m vendidos =")
for produto, quantidade in menos_vendido_2.items():
    print(f"{produto} com: {quantidade} unid")
lista_produt_Lj3 = loja_3['Produto'].value_counts()
mais_vendido_3 = lista_produt_Lj3.nlargest(6)
print('\n\033[31mLOJA 3\033[0m - Produtos \033[31mMAIS\033[0m vendidos:')
for produto, quantidade in mais_vendido_3.items():
  print(f'{produto} com: {quantidade} unid')
menos_vendido_3 = lista_produt_Lj3.nsmallest(6)
print("\n\033[31mLOJA 3\033[0m -Produtos \033[31mMENOS\033[0m vendidos =")
for produto, quantidade in menos_vendido_3.items():
    print(f"{produto} com: {quantidade} unid")
lista_produt_Lj4 = loja_4['Produto'].value_counts()
mais_vendido_4 = lista_produt_Lj4.nlargest(6)
print('\n\033[31mLOJA 4\033[0m - Produtos \033[31mMAIS\033[0m vendidos:')
for produto, quantidade in mais_vendido_4.items():
  print(f'{produto} com: {quantidade} unid')
menos_vendido_4 = lista_produt_Lj4.nsmallest(6)
print("\n\033[31mLOJA 4\033[0m -Produtos \033[31mMENOS\033[0m vendidos =")
for produto, quantidade in menos_vendido_4.items():
    print(f"{produto} com: {quantidade} unid")
# Out:
# LOJA 1- Produtos MAIS vendidos:
# Micro-ondas com: 60 unid
# TV Led UHD 4K com: 60 unid
# Guarda roupas com: 60 unid
# Secadora de roupas com: 58 unid
# Cômoda com: 56 unid
# Blocos de montar com: 56 unid
#
# LOJA 1 -Produtos MENOS vendidos =
# Headset com: 33 unid
# Celular ABXY com: 33 unid
# Panela de pressão com: 35 unid
# Pandeiro com: 36 unid
# Mochila com: 39 unid
# Ciência de dados com python com: 39 unid
#
# LOJA 2- Produtos MAIS vendidos:
# Iniciando em programação com: 65 unid
# Micro-ondas com: 62 unid
# Bateria com: 61 unid
# Violão com: 58 unid
# Pandeiro com: 58 unid
# Secadora de roupas com: 57 unid
#
# LOJA 2 -Produtos MENOS vendidos =
# Jogo de tabuleiro com: 32 unid
# Mesa de jantar com: 34 unid
# Impressora com: 34 unid
# Poltrona com: 35 unid
# Fone de ouvido com: 37 unid
# Assistente virtual com: 38 unid
#
# LOJA 3 - Produtos MAIS vendidos:
# Kit banquetas com: 57 unid
# Mesa de jantar com: 56 unid
# Cama king com: 56 unid
# Jogo de panelas com: 55 unid
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete_1 = loja_1['Frete'].mean().round(2)
print(f"Loja 1 - O frete médio gasto foi de R${frete_1:.2f}")
frete_2 = loja_2['Frete'].mean().round(2)
print(f"Loja 2 - O frete médio gasto foi de R${frete_2:.2f}")
frete_3 = loja_3['Frete'].mean().round(2)
print(f"Loja 3 - O frete médio gasto foi de R${frete_3:.2f}")
frete_4 = loja_4['Frete'].mean().round(2)
print(f"Loja 4 - O frete médio gasto foi de R${frete_4:.2f}")
# Out:
# Loja 1 - O frete médio gasto foi de R$34.69
# Loja 2 - O frete médio gasto foi de R$33.62
# Loja 3 - O frete médio gasto foi de R$33.07
# Loja 4 - O frete médio gasto foi de R$31.28

# %%
# Grafico de Linha para FRETES

# %%
fretes_total = [frete_1, frete_2, frete_3, frete_4]

plt.figure(figsize=(10, 6))

for i, (storesi, fretes_totali) in enumerate(zip(stores, fretes_total)):
    plt.annotate(f' {fretes_totali}', (storesi, fretes_totali), textcoords="offset points", xytext=(0, 7), ha='center')

plt.title('Gráfico Gasto com Frete das Lojas', color='red')
plt.plot(stores, fretes_total)
plt.xlabel('stores', color='green')
plt.ylabel('Frete Médio', color='y')
plt.grid(True)
plt.show()

# %%
# RELATÓRIO - Conclusão final

# %% [markdown]
# Relatório  de Analise de Performance baseado nos indicadores apresentados:
#
# Pelas informações apresentadas referente as 4 lojas e com uma Analise baseado somente nestes indicadores  não é possivel ter um veredico conclusívo de qual loja tem o pior desempenho. Para fazer um diagnostico conclusivo de qual loja deveria ser vendida a analise precisaria ser feita com informações complementares. Analisando somente o "faturamento" cairiamos no erro de indicar a **"loja 4"** que neste quesito teve o pior desempenho não é correto porque quando comparado com a média de faturamento das outras 3 lojas a diferença é inferior a 7,5%. Entretanto nos outros 3 indicadores que são: **frete** ( teve o menor valor médio), **Avaliações do Consumidor** obteve o 2º melhor desempenho e nas **Vendas por Categoria** só perdeu nas categorias eletrodomesticos e instrumentos musicais porem superou nas categorias: "brinquedos" e "utilidade domesticas". Proponho que: antes de se desfazer de uma loja seria melhor fazer uma analise mais profunda incluindo tambem o indicador **"lucratividade por loja", **que é um indicador ainda mais importante do que só o faturamento. Dependendo do resultado da analise com mais informações talves a proposta seria a de subir o faturamento da loja 4. E o recomendado seria primeiro implementar um "**Plano de Negocio**" com uma adequação dos mix de produtos para impulsinar as vendas dos produtos de melhor valor agregado para crescer o grupo como um todo.
